# %%
import os
import re
import pandas as pd
import PRData


current_month = 'July 2016' #MOVE TO CONFIG

data = PRData.data_pull()

# %%
data
# Out:
#              DATE             CITY STATE COUNTRY  \
# 0       July 2016      LOS ANGELES    CA      US
# 1       July 2016     MOUNT LAUREL    NJ      US
# 2       July 2016         SAN JOSE    CA      US
# 3       July 2016         SAN JOSE    CA      US
# 4       July 2016     WALNUT CREEK    CA      US
# 5       July 2016        FLAGSTAFF    AZ      US
# 6       July 2016     WALNUT CREEK    CA      US
# 8       July 2016    SAN FRANCISCO    CA      US
# 9       July 2016         SAN JOSE    CA      US
# 10      July 2016          HOUSTON    TX      US
# 11      July 2016    SAN FRANCISCO    CA      US
# 12      July 2016         BEAUMONT    TX      US
# 13      July 2016     WALNUT CREEK    CA      US
# 14      July 2016     WALNUT CREEK    CA      US
# 15      July 2016         HAMILTON    OH      US
# 16      July 2016      SPRINGFIELD    OH      US
# 17      July 2016           AUSTIN    TX      US
# 18      July 2016           DAYTON    OH      US
# ...
